# %% [markdown]
# <a href="https://colab.research.google.com/github/deshmukhamol100/DS_practice/blob/main/Vecror_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install chromadb
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.6/21.6 MB 65.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 20.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 78.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 80.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.1/72.1 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.0/142.0 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.7/68.7 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.6/231.6 kB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.38.0
# ...

# %%
import chromadb

# %% [markdown]
# genai engineer
#       -- new artical knowledge base 1 context - collection1 - new
#
#       --Sport artical - knowledge base2 - context- collection2-news
#
#       --finacial -knowldge base3 - context-collection3- finance
#
#       --education-knowledge base4 - context-collection4-educations

# %% [markdown]
# two ways
#
#
#
# 1. client in memory - once close this cant retrive
# 2. persistant client - folder (can see in chromadb folder)

# %%
# client in memory
 client = chromadb.Client()
# Out:
#   File "/tmp/ipykernel_521/3160180039.py", line 2
#     client = chromadb.Client()
#     ^
# IndentationError: unexpected indent

# %%
client = chromadb.Client()

# %%
type(client)
# Out:
# chromadb.api.client.Client

# %%
# create persistance client
client = chromadb.PersistentClient(path="./News_vector_db")

# %%
# creating collection
new_collection = client.create_collection(name="news")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /tmp/ipykernel_521/3174239532.py in <cell line: 0>()
#       1 # creating collection
# ----> 2 new_collection = client.create_collection(name="news")
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/client.py in create_collection(self, name, schema, configuration, metadata, embedding_function, data_loader, get_or_create)
#     220             configuration["embedding_function"] = embedding_function
#     221
# --> 222         model = self._server.create_collection(
#     223             name=name,
#     224             schema=schema,
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/rust.py in create_collection(self, name, schema, configuration, metadata, get_or_create, tenant, database)
#     242             schema_str = None
#     243
# --> 244         collection = self.bindings.create_collection(
# ...

# %%
# 3. get the collerction
client.get_collection(name="news")
# Out:
# Collection(name=news)

# %%
# delete the collection
client.delete_collection(name="news")

# %%
#clinet -> collection -> knowledge -

# %%
new_collection.add(
    documents=["This is a document", "This is another document","Amol Deshmukh"],
    ids=["id1", "id2"]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_521/1694478629.py in <cell line: 0>()
# ----> 1 new_collection.add(
#       2     documents=["This is a document", "This is another document","Amol Deshmukh"],
#       3     ids=["id1", "id2"]
#       4 )
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/models/Collection.py in add(self, ids, embeddings, metadatas, documents, images, uris)
#     105         """
#     106
# --> 107         add_request = self._validate_and_prepare_add_request(
#     108             ids=ids,
#     109             embeddings=embeddings,
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/models/CollectionCommon.py in wrapper(self, *args, **kwargs)
#     101         def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#     102             try:
# --> 103                 return func(self, *args, **kwargs)
# ...

# %%
new_collection.add(
    documents=["This is a document", "This is another document","Amol Deshmukh"],
    ids=["id3"]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_521/557174249.py in <cell line: 0>()
# ----> 1 new_collection.add(
#       2     documents=["This is a document", "This is another document","Amol Deshmukh"],
#       3     ids=["id3"]
#       4 )
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/models/Collection.py in add(self, ids, embeddings, metadatas, documents, images, uris)
#     105         """
#     106
# --> 107         add_request = self._validate_and_prepare_add_request(
#     108             ids=ids,
#     109             embeddings=embeddings,
#
# /usr/local/lib/python3.12/dist-packages/chromadb/api/models/CollectionCommon.py in wrapper(self, *args, **kwargs)
#     101         def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#     102             try:
# --> 103                 return func(self, *args, **kwargs)
# ...

# %%
new_collection_embeding = new_collection.peek()

# %%
print(new_collection_embeding['embeddings'][0])
# Out:
# [-6.60278797e-02  1.71504959e-01 -5.89271716e-04  1.81421861e-02
#   2.39836983e-03  1.10479686e-02 -2.69648097e-02  2.81046089e-02
#   3.56519111e-02  5.12004271e-02  7.24255573e-04  7.43272528e-02
#  -1.49707627e-02 -2.22006217e-02 -1.13536827e-01  1.76234227e-02
#  -5.49539700e-02 -1.66425190e-03  7.02937227e-03  6.25418946e-02
#   3.15764323e-02  1.31080836e-01  7.02711381e-03 -1.33964848e-02
#   2.29830854e-02  7.59554505e-02 -8.90459195e-02  1.89128034e-02
#   6.10037744e-02 -2.68605389e-02  1.90913193e-02  5.66347167e-02
#   9.58642364e-02  2.44228039e-02  2.42364779e-02  2.77040172e-02
#   6.22565113e-02 -5.70596196e-03  4.22521085e-02  3.13465856e-02
#  -1.21393921e-02 -9.77006257e-02 -3.68249379e-02  1.91436745e-02
#   9.72433574e-03  4.50822599e-02 -8.10640752e-02  4.47826833e-03
#  -5.48447482e-02  3.64378430e-02 -6.53682798e-02 -4.64270823e-02
#  -7.93092623e-02 -2.43491177e-02  3.98684107e-02  6.55394420e-02
# ...

# %%
new_collection.query(
    query_texts=["what is in documents related to ? "],
    n_results=1
)
# Out:
# {'ids': [['id1']],
#  'embeddings': None,
#  'documents': [['This is a document']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None]],
#  'distances': [[0.7244306802749634]]}

# %%
new_collection.add(
    documents=["name is amol", "working in PS","Amol Deshmukh"],
    ids=["id4", "id5", "id6"]
)

# %%
new_collection.query(
    query_texts=["what is name ? "],
    n_results=1
)
# Out:
# {'ids': [['id4']],
#  'embeddings': None,
#  'documents': [['name is amol']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[None]],
#  'distances': [[1.1695549488067627]]}
