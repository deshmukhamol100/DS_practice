# %%
first_name = 'AMOL'
last_name = 'DESHMUKH'
city = 'PUNE'
state= 'MAHARASHTRA'
country = 'INDIA'
age =37
Is_married = 'TRUE'
skills = ['pySpark','Python','SQL','AWS','Azure']
person_info = {
    'firstname' : 'Amol',
    'lastname' : 'DESHMUKH',
    'country' : 'INDIA',
    'city' : 'PUNE'
    }

# %% [markdown]
# # printing the values stored in the variable

# %%
print(first_name)
print(len(first_name))
print(last_name)
print(len(last_name))
print(country)
print(city)
print(age)
print(Is_married)
print(skills)
print(person_info)

# %%
print('First Name :',first_name)
print('Last Name :',last_name)
print('City :',city)
print('State :',state)
print('Country :',country)

# %% [markdown]
# # Declaring multiple variables in one frame

# %%
first_name,last_name,country,age,Is_married = "Amol","DESHMUKH","INDIA","37","TRUE"

# %%
print(first_name,last_name,country,age,Is_married)
print(first_name)
print(last_name)
print(country)
print(age)
print(Is_married)
