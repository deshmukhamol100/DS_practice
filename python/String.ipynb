# %%
s1="welcomeTeam"
s1
# Out:
# 'welcomeTeam'

# %%
len(s1)
# Out:
# 11

# %%
s1[0]
# Out:
# 'w'

# %%
s1[-1]
# Out:
# 'm'

# %% [markdown]
# --in slicing left index always start pint from 0 and right index -1

# %% [markdown]
# --emplty slicer means print all the string [:]

# %%
s1[:]
# Out:
# 'welcomeTeam'

# %%
s1[2:10]
# Out:
# 'lcomeTea'

# %% [markdown]
# --when left space empty then it start from bigining
# --[10:] when right is empty
# --[:10] till W to a

# %%
s1[:10]
# Out:
# 'welcomeTea'

# %%
s1[9:]
# Out:
# 'am'

# %% [markdown]
# --s1[left : right] ,, s1[left:right:step]

# %%
s1[::3]
# Out:
# 'wcea'

# %% [markdown]
# --forward slicing -->[2:8:3]<br> --backworad slicing [-10:-3:-2]

# %%
s1[2:8:2]
# Out:
# 'loe'

# %%
s1[-9:-1:3]
# Out:
# 'lme'

# %% [markdown]
# --revece string s1[::-1]

# %%
s1[::-1]
# Out:
# 'maeTemoclew'

# %% [markdown]
# BOTMAS

# %%
txt ="  my name is amol "

# %%
txt.lstrip()
# Out:
# 'my name is amol '

# %%
txt.rstrip()
# Out:
# '  my name is amol'

# %%
spam = 1
text ="# This is not a comment because its inside quotes"

# %%
2+2
# Out:
# 4

# %%
(50-5*6)/4
# Out:
# 5.0

# %%
8/5
# Out:
# 1.6

# %%
17/3
# Out:
# 5.666666666666667

# %%
17//3#floor division
# Out:
# 5

# %%
17%3 #modulo operator
# Out:
# 2

# %%
5*3+2 #order of operations
# Out:
# 17

# %%
2**7 #exponentiation
# Out:
# 128

# %%
widht = 20
height = 5*9
area = widht*height
area
# Out:
# 900

# %%
n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 n
#
# NameError: name 'n' is not defined

# %% [markdown]
# # string

# %%
'Amol deshmukh'
# Out:
# 'Amol deshmukh'

# %%
"Amol deshmukh"
# Out:
# 'Amol deshmukh'

# %%
"1989"
# Out:
# '1989'

# %%
"don't"
# Out:
# "don't"

# %%
'doesn\'t'
# Out:
# "doesn't"

# %%
'"yes", he said.'
# Out:
# '"yes", he said.'

# %%
"\"yes\", he said."
# Out:
# '"yes", he said.'

# %%
s="first line.\nsecond line."
s
# Out:
# 'first line.\nsecond line.'

# %%
print(s)
# Out:
# first line.
# second line.

# %%
print("""\
Usage thing [options]
-h
-h Hostname
""")
# Out:
# Usage thing [options]
# -h
# -h Hostname

# %% [markdown]
# # concatenated

# %%
3*'un' + 'ium'
# Out:
# 'unununium'

# %%
'py' 'thon'
# Out:
# 'python'

# %%
w='python'
w
# Out:
# 'python'

# %%
w[2]
# Out:
# 't'

# %%
w[0]
# Out:
# 'p'

# %%
w[-1]
# Out:
# 'n'

# %%
w[-2]
# Out:
# 'o'

# %%
w[0:6]
# Out:
# 'python'

# %%
w[1:6]
# Out:
# 'ython'

# %%
w[-1:-6]
# Out:
# ''

# %%
w[0:4]+w[4:6]
# Out:
# 'python'

# %%
w[42]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 w[42]
#
# IndexError: string index out of range

# %%
w[-45]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 w[-45]
#
# IndexError: string index out of range

# %%
j+w[1:6]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 j+w[1:6]
#
# NameError: name 'j' is not defined

# %%
'j'+w[1:6]
# Out:
# 'jython'

# %%
s ="IndiawillplayagainstEnglandinMUmbai"
s
# Out:
# 'IndiawillplayagainstEnglandinMUmbai'
