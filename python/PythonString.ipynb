# %%
s1="welcomeTeam"
s1
# Out:
# 'welcomeTeam'

# %%
len(s1)
# Out:
# 11

# %%
s1[0]
# Out:
# 'w'

# %%
s1[-1]
# Out:
# 'm'

# %% [markdown]
# --in slicing left index always start pint from 0 and right index -1

# %% [markdown]
# --emplty slicer means print all the string [:]

# %%
s1[:]
# Out:
# 'welcomeTeam'

# %%
s1[2:10]
# Out:
# 'lcomeTea'

# %% [markdown]
# --when left space empty then it start from bigining
# --[10:] when right is empty
# --[:10] till W to a

# %%
s1[:10]
# Out:
# 'welcomeTea'

# %%
s1[9:]
# Out:
# 'am'

# %% [markdown]
# --s1[left : right] ,, s1[left:right:step]

# %%
s1[::3]
# Out:
# 'wcea'

# %% [markdown]
# --forward slicing -->[2:8:3]<br> --backworad slicing [-10:-3:-2]

# %%
s1[2:8:2]
# Out:
# 'loe'

# %%
s1[-9:-1:3]
# Out:
# 'lme'

# %% [markdown]
# --revece string s1[::-1]

# %%
s1[::-1]
# Out:
# 'maeTemoclew'

# %% [markdown]
# BOTMAS
