# %% [markdown]
# # list

# %%
l1=[10,20,30,40,50];
l2=[100,200,300,400,500];
print(l1);

# %%
#l1.extend(l2)
l2=[100,200,300,400,500];
l1=[10,20,30,40,50];


print(l2.extend(l1));
# Out:
# None

# %%
l1.index(30)
# Out:
# 2

# %%
for i in l2:
    print(i)
# Out:
# 100
# 200
# 300
# 400
# 500
# 10
# 20
# 30
# 40
# 50

# %%
l1.insert(2,25)
print(l1)
# Out:
# [10, 20, 25, 25, 25, 25, 25, 25, 25, 25, 25]

# %%
l1=[10,20,30,40,50];
l1.remove(25)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 2
#       1 l1=[10,20,30,40,50];
# ----> 2 l1.remove(25)
#
# ValueError: list.remove(x): x not in list

# %%
print(l1)
# Out:
# [10, 20, 25, 25, 25, 25, 25, 25, 25, 25]

# %% [markdown]
# # pop()
# --if you dont pass anything then it will remove last value and dispay removed values <br> if pass vlaue it remove element of that index number

# %%
l1.pop()
print(l1)
l1.pop(2)
print(l1)
# Out:
# [10, 20, 25]
# [10, 20]

# %% [markdown]
# # remove()
# --remove values by value name <br>
# pop() remov element by index <br>
# remove() remove element by value

# %%
L1.REMOVE(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 L1.REMOVE(25)
#
# NameError: name 'L1' is not defined
