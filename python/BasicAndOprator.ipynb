# %% [markdown]
# # Arithmetic Operators

# %%
x1 , y1 = 10 , 3

# %%
x1 ^ y1
# Out:
# 9

# %%
x1 + y1
# Out:
# 13

# %%
x1 - y1
# Out:
# 7

# %%
x1 * y1
# Out:
# 30

# %%
x1 / y1
# Out:
# 3.3333333333333335

# %%
x1//y1
# Out:
# 3

# %%
x1%y1
# Out:
# 1

# %%
x1 ** y1
# Out:
# 1000

# %%
x2 = 3
y2 = 2
x2 ** y2
# Out:
# 9

# %% [markdown]
# # Assignment Operator

# %%
x = 2

# %%
x = x + 2

# %%
x
# Out:
# 6

# %%
x += 2
x
# Out:
# 6

# %%
x -= 3

# %%
x
# Out:
# 3

# %%
x
# Out:
# 3

# %%
x *=3

# %%
x
# Out:
# 9

# %%
x /= 2

# %%
x = 9
x //= 2

# %%
x
# Out:
# 4

# %% [markdown]
# # Unaray operator

# %%
n = 8
n
# Out:
# 8

# %%
m =-(n)
m
# Out:
# -8

# %%
n
# Out:
# 8

# %%
-n
# Out:
# -8

# %%
-n=4
# Out:
#   Cell In[28], line 1
#     -n=4
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# # Relational Operator

# %%
a = 5
b = 6

# %%
a < b
# Out:
# True

# %%
b>a
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
b = 5

# %%
a>= b
# Out:
# True

# %%
a<= b
# Out:
# True

# %%
a!=b
# Out:
# False

# %%
a == b
# Out:
# True

# %% [markdown]
# # logical Operator

# %%
a = 5
b = 4

# %%
a < 8 and b > 3
# Out:
# True

# %%
a < 1 and b <5
# Out:
# False

# %%
a == 0 and b==0
# Out:
# False

# %%
a < 5 or b > 3
# Out:
# True

# %%
a ==0 or b ==4
# Out:
# True

# %%
a> 8 or b>2
# Out:
# True

# %%
x = -4
not x
# Out:
# False

# %%
x = False
x
# Out:
# False

# %%
not x
# Out:
# True
