# %% [markdown]
# # number system <br>
# --Decimal -> base2 <br>--all remider is decimal points<BR> -- HexaDesimal ->base10<br> --hexadecimal->base16<br>--Ocatal -> base8

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(0b11001)
# Out:
# 25

# %% [markdown]
# --octal

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(25)
# Out:
# '0x19'

# %%
hex(0)
# Out:
# '0x0'

# %% [markdown]
# #BITWISE OPERATER

# %% [markdown]
# --compliment<br>
# --memory we cant store -ve values only 1 way ti store -ve vlaue is ~ <br> 1complemnt +1 == store with 1

# %%
12 & 13
# Out:
# 12

# %%
bin(13)
# Out:
# '0b1101'

# %%
12 | 13 #bitweise or
# Out:
# 13

# %%
12 & 13 #bitwise and
# Out:
# 12

# %% [markdown]
# #XOR^

# %%
12^13 #bitwise xor
# Out:
# 1

# %%
13^12 #bitwise xor
# Out:
# 1

# %% [markdown]
# #left shift << <br>
# --we gain the bit<br>
# #right shift >> <br>
# --we loss the bit

# %%
12 << 1
# Out:
# 24

# %%
12<<2 #left shift
# Out:
# 48

# %%
12<<3 #left shift
# Out:
# 96

# %% [markdown]
# #right shift

# %%
12>>1
# Out:
# 6

# %%
12>>2
# Out:
# 3

# %%
12>>3
# Out:
# 1

# %%
15>>2
# Out:
# 3

# %%
import math

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
pi=3.14
pi
# Out:
# 3.14

# %%
math.floor(pi)
# Out:
# 3

# %%
math.ceil(pi)
# Out:
# 4

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import math as m
print(m.pow(2, 3))
print(m.sqrt(25))
print(m.ceil(pi))
print(m.floor(pi))
# Out:
# 8.0
# 5.0
# 4
# 3

# %% [markdown]
# # input() function

# %%
x = int(input(5))
y = int(input(10 ))
z=x+y
print(z)5
6
# Out:
#   Cell In[27], line 4
#     print(z)5
#             ^
# SyntaxError: invalid syntax
