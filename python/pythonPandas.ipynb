# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.1'

# %%
data = pd.read_csv("/workspaces/DS_practice/python/Project/Data/data.csv")

# %%
data
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
type(data)
# Out:
# pandas.DataFrame

# %%
#lenght of data
len(data)
# Out:
# 195

# %%
#check coulumns
data.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')

# %%
len(data.columns)
# Out:
# 5

# %%
data.shape
# Out:
# (195, 5)

# %%
#check null values
data.isnull()
#data.isnull().sum()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
data.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
#check first 5 rows
data.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
data.describe()# statistical summary of the data only numeric columns
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_cat = data[['CountryName', 'CountryCode', 'IncomeGroup']]
df_cat.head(2)
# Out:
#    CountryName CountryCode  IncomeGroup
# 0        Aruba         ABW  High income
# 1  Afghanistan         AFG   Low income

# %%
df_num = data[['BirthRate', 'InternetUsers']]
df_num.head(2)
# Out:
#    BirthRate  InternetUsers
# 0     10.244           78.9
# 1     35.253            5.9

# %%
print(data.columns)
print(df_cat.columns)
print(df_num.columns)
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')
# Index(['CountryName', 'CountryCode', 'IncomeGroup'], dtype='str')
# Index(['BirthRate', 'InternetUsers'], dtype='str')

# %%
print(df_cat.info())
print(df_num.info())    
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountryName  195 non-null    str
#  1   CountryCode  195 non-null    str
#  2   IncomeGroup  195 non-null    str
# dtypes: str(3)
# memory usage: 4.7 KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   BirthRate      195 non-null    float64
#  1   InternetUsers  195 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    str
#  1   CountryCode    195 non-null    str
#  2   BirthRate      195 non-null    float64
# ...

# %%
df_cat.describe()
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
df_num.describe()
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
data.columns= ['a', 'b', 'c', 'd', 'e']

# %%
data.head(10)
# Out:
#                       a    b       c        d                    e
# 0                 Aruba  ABW  10.244  78.9000          High income
# 1           Afghanistan  AFG  35.253   5.9000           Low income
# 2                Angola  AGO  45.985  19.1000  Upper middle income
# 3               Albania  ALB  12.877  57.2000  Upper middle income
# 4  United Arab Emirates  ARE  11.044  88.0000          High income
# 5             Argentina  ARG  17.716  59.9000          High income
# 6               Armenia  ARM  13.308  41.9000  Lower middle income
# 7   Antigua and Barbuda  ATG  16.447  63.4000          High income
# 8             Australia  AUS  13.200  83.0000          High income
# 9               Austria  AUT   9.400  80.6188          High income

# %%
data.columns =['CountryName', 'CountryCode', 'IncomeGroup', 'BirthRate', 'InternetUsers']

# %%
data.head(10)
# Out:
#             CountryName CountryCode  IncomeGroup  BirthRate  \
# 0                 Aruba         ABW       10.244    78.9000
# 1           Afghanistan         AFG       35.253     5.9000
# 2                Angola         AGO       45.985    19.1000
# 3               Albania         ALB       12.877    57.2000
# 4  United Arab Emirates         ARE       11.044    88.0000
# 5             Argentina         ARG       17.716    59.9000
# 6               Armenia         ARM       13.308    41.9000
# 7   Antigua and Barbuda         ATG       16.447    63.4000
# 8             Australia         AUS       13.200    83.0000
# 9               Austria         AUT        9.400    80.6188
#
#          InternetUsers
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
data[data['InternetUsers'] < 2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 data[data['InternetUsers'] < 2]
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/ops/common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/arraylike.py:50, in OpsMixin.__lt__(self, other)
#      48 @unpack_zerodim_and_defer("__lt__")
#      49 def __lt__(self, other):
# ---> 50     return self._cmp_method(other, operator.lt)
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/series.py:6735, in Series._cmp_method(self, other, op)
#    6732 lvalues = self._values
# ...

# %% [markdown]
# # find record bithrate are greate than 40

# %%
data['BirthRate']
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: BirthRate, Length: 195, dtype: float64

# %%
data['BirthRate'] < 40
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 190     True
# 191    False
# 192     True
# 193     True
# 194     True
# Name: BirthRate, Length: 195, dtype: bool

# %%
data[data['BirthRate'] < 40 and data['InternetUsers'] < 2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2049/824262027.py in ?()
# ----> 1 data[data['BirthRate'] < 40 and data['InternetUsers'] < 2]
#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pandas/core/generic.py in ?(self)
#    1511     @final
#    1512     def __bool__(self) -> NoReturn:
# -> 1513         raise ValueError(
#    1514             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1515             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1516         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
data['InternetUsers'] = pd.to_numeric(data['InternetUsers'], errors='coerce')
print(f"Column converted to: {data['InternetUsers'].dtype}")
# Out:
# Column converted to: float64

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)

# %%
vis1 = sns.distplot(data['BirthRate'])
# Out:
# /tmp/ipykernel_2049/714039129.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis1 = sns.distplot(data['BirthRate'])

# %%
vis2 = sns.distplot(data['InternetUsers'])# we get line plot instead of histogram because of the null values in the data
# Out:
# /tmp/ipykernel_2049/702775162.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis2 = sns.distplot(data['InternetUsers'])#
# /usr/local/python/3.12.1/lib/python3.12/site-packages/seaborn/distributions.py:2464: RuntimeWarning: Mean of empty slice
#   line, = ax.plot(a.mean(), 0)
# /usr/local/python/3.12.1/lib/python3.12/site-packages/numpy/_core/_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/python/3.12.1/lib/python3.12/site-packages/numpy/lib/_histograms_impl.py:897: RuntimeWarning: invalid value encountered in divide
# ...

# %%
vis2 = sns.displot(data['InternetUsers'])# we get line plot instead of histogram because of the null values in the data

# %%
# different between distplot and displot is that distplot is used for univariate distribution and displot is used for bivariate distribution

# %%
vis3 = sns.distplot(data['BirthRate'], bins=15)
# Out:
# /tmp/ipykernel_2049/419768168.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis3 = sns.distplot(data['BirthRate'], bins=15)

# %%
vis4 = sns.distplot(data['InternetUsers'], bins=50, kde=False)
# Out:
# /tmp/ipykernel_2049/2707934774.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   vis4 = sns.distplot(data['InternetUsers'], bins=50, kde=False)
# /usr/local/python/3.12.1/lib/python3.12/site-packages/seaborn/distributions.py:2464: RuntimeWarning: Mean of empty slice
#   line, = ax.plot(a.mean(), 0)
# /usr/local/python/3.12.1/lib/python3.12/site-packages/numpy/_core/_methods.py:142: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# -- plot the graph using 1 variable called univariante analysis<br>
# -- plot the graph using 2 variable called baivariante analysis<Br>
# -- plot the graph using 1 variable called multivariante analysis

# %%
data
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
vis5 = sns.boxenplot(data=data,x='IncomeGroup', y='BirthRate')

# %% [markdown]
# -- Outlier - in stats is the data point which is very far from other observations<br> to adjust this type of data

# %%
vis6 = sns.lmplot(data=data, x='BirthRate', y='InternetUsers', )# we get line plot instead of scatter plot because of the null values in the data

# %% [markdown]
# # make evenry income group with diffeant color

# %%
vis7 = sns.lmplot(data=data, x='BirthRate', y='InternetUsers', hue='IncomeGroup')

# %%
vis8 =sns.lineplot(data=data, x='BirthRate', y='InternetUsers', hue='IncomeGroup', marker='o')
